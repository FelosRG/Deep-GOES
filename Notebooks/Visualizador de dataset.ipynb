# %%
import os
import h5py
import numpy as np
import matplotlib.pyplot as plt

DATASET  = "dataset.h5"

DIR_REPO = "/".join(os.getcwd().split("/")[:-1])
DIR_DATASETS = f"{DIR_REPO}/gendata/Datasets"
path_dataset = f"{DIR_DATASETS}/{DATASET}"

print("Variables disponibles:")
with h5py.File(path_dataset,"r") as file:
    keys = file.keys()
    for key in keys:
        print(key," : ",file[key].shape)
        
# Algunas funciones útiles

def extraer_variable(variable):
    with h5py.File(path_dataset,"r") as file:
        array = file[variable][:]
    return array


def plot_histograma(array,bins=30):
    array = array.reshape(-1)
    n,_,_ = plt.hist(array,bins=bins,density=True,stacked=False)
    plt.show()
    return n
    
def plot_ejemplos(array,vmin,vmax):
    num_t = array.shape[0]
    num_l = array.shape[1]
    array = array.reshape((num_t*num_l,*array.shape[2:]))
    array = array[index]
    fig , ax = plt.subplots(1,num_ejemplos)
    for i in range(num_ejemplos):
        ax[i].imshow(array[i],vmin=vmin,vmax=vmax)
        ax[i].axis("off")
    plt.show()
# Out:
# Variables disponibles:
# 10  :  (432, 900, 37, 37)
# 14  :  (432, 900, 37, 37)
# 16  :  (432, 900, 37, 37)
# 4  :  (432, 900, 37, 37)
# 6  :  (432, 900, 37, 37)
# 8  :  (432, 900, 37, 37)
# 9  :  (432, 900, 37, 37)
# Altura  :  (900, 37, 37)
# CAPE  :  (432, 900, 37, 37)
# CM  :  (432, 900, 37, 37)
# COD  :  (432, 900, 37, 37)
# CTH  :  (432, 900, 37, 37)
# CTP  :  (432, 900, 37, 37)

# %%
num_t = 432
num_l = 900
num_ejemplos = 7
index = np.random.randint(0,num_t*num_l,num_ejemplos)

# %% [markdown]
# ### Variable: Banda 4

# %%
array = extraer_variable("4")

# %%
_ = plot_histograma(array)

# %%
vmin,vmax = 0,20
plot_ejemplos(array,vmin,vmax)

# %% [markdown]
# ### Variable: Banda 6

# %%
array = extraer_variable("6")

# %%
_ = plot_histograma(array)

# %%
vmin,vmax = 0,10
plot_ejemplos(array,vmin,vmax)

# %% [markdown]
# ### Variable: Banda 8

# %%
array = extraer_variable("8")

# %%
_ = plot_histograma(array)

# %%
vmin,vmax = 0.5,3
plot_ejemplos(array,vmin,vmax)

# %% [markdown]
# ### Variable: Banda 9

# %%
array = extraber_variable("9")

# %%
_ = plot_histograma(array)

# %%
vmin,vmax = 1.8,8.2
plot_ejemplos(array,vmin,vmax)

# %% [markdown]
# ### Variable: Banda 10

# %%
array = extraer_variable("10")

# %%
_ = plot_histograma(array)

# %%
vmin,vmax = 2.2,16
plot_ejemplos(array,vmin,vmax)

# %% [markdown]
# ### Variable: Banda 14

# %%
array = extraer_variable("14")

# %%
_ = plot_histograma(array)

# %%
vmin,vmax = 20,130
plot_ejemplos(array,vmin,vmax)

# %% [markdown]
# ### Variable: Banda 16

# %%
array = extraer_variable("16")

# %%
_ = plot_histograma(array)

# %%
vmin,vmax = 30,115
plot_ejemplos(array,vmin,vmax)

# %% [markdown]
# ### Variable: Cloud Binary Mask (CBM)

# %%
array = extraer_variable("CM")

# %%
n = plot_histograma(array,bins=3)
print("Pesos en clasificación:")
print(n)
# Out:
# [0.83119398 0.         2.16880612]

# %%
vmin,vmax = 0,1
plot_ejemplos(array,vmin,vmax)

# %% [markdown]
# ### Variable: Cloud Top Height (CTH)

# %%
array = extraer_variable("CTH")

# %%
plot_histograma(array)

# %%
vmin,vmax = 0,14_500
plot_ejemplos(array,vmin,vmax)

# %% [markdown]
# ### Variable: Cloud Optical Depth (COD)

# %%
array = extraer_variable("COD")

# %%
plot_histograma(array)

# %%
vmin,vmax = 0,30
plot_ejemplos(array,vmin,vmax)

# %% [markdown]
# ### Variable: CAPE

# %%
array = extraer_variable("CAPE")

# %%
plot_histograma(array)

# %%
vmin,vmax = 0,250
plot_ejemplos(array,vmin,vmax)

# %% [markdown]
# ### Variable: Cloud Top Phase

# %%
array = extraer_variable("CTP")

# %%
n = plot_histograma(array,bins=5)
print("Pesos en clasificación:")
print(n)
# Out:
# [0.23024386 0.29872673 0.05114073 0.03663977 0.63324895]

# %%
vmin,vmax = 0,4
plot_ejemplos(array,vmin,vmax)

# %% [markdown]
# ### Variable Altura

# %%
array = extraer_variable("Altura")

# %%
_ = plot_histograma(array)
